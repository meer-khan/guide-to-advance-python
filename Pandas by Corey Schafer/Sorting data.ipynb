# %% [markdown]
# # Sorting data

# %%
import pandas as pd 
import numpy as np

# %%
#  dummy dictionary to convert it into dataframe

data = {
    'first_name': ['Alice', 'Bob', 'Charlie', 'David'],
    'last_name': ['Pretty', 'Chura', 'BC', 'BSDK'],
    'age': [25, 32, 18, 47],
    'city': ['New York', 'Paris', 'London', 'San Francisco'],
    'salary':[10000,120000,125000,105000]
}

# %%
data = pd.DataFrame(data)

# %%
df = pd.read_csv("CSVs\survey_results_public.csv")

# %%
# Sorting dataframe by "last_name"
data.sort_values(by="last_name")
# Out:
#   first_name last_name  age           city  salary
# 2    Charlie        BC   18         London  125000
# 3      David      BSDK   47  San Francisco  105000
# 1        Bob     Chura   32          Paris  120000
# 0      Alice    Pretty   25       New York   10000

# %%
# we can set the ascending argument to False to sort the values in descending order
# sort_values() also has inplace argument
data.sort_values(by="last_name", ascending=False)
# Out:
#   first_name last_name  age           city  salary
# 0      Alice    Pretty   25       New York   10000
# 1        Bob     Chura   32          Paris  120000
# 3      David      BSDK   47  San Francisco  105000
# 2    Charlie        BC   18         London  125000

# %% [markdown]
# ## Sorting on multiple columns

# %%
data.sort_values(by=["last_name","first_name"], ascending=False)

# first pandas sort the inner level which is "first_name" and then sort the upper level which is "last_name"
# Out:
#   first_name last_name  age           city  salary
# 0      Alice    Pretty   25       New York   10000
# 1        Bob     Chura   32          Paris  120000
# 3      David      BSDK   47  San Francisco  105000
# 2    Charlie        BC   18         London  125000

# %%
# ascending and descending on multiple columns
data.sort_values(by=["last_name","first_name"], ascending=[False,True])

# first pandas do sorting with ascending True on inner level which is "first_name" and than upper level with descending order
# on "last_name"
# Out:
#   first_name last_name  age           city  salary
# 0      Alice    Pretty   25       New York   10000
# 1        Bob     Chura   32          Paris  120000
# 3      David      BSDK   47  San Francisco  105000
# 2    Charlie        BC   18         London  125000

# %% [markdown]
# ## Sorting on series

# %%
data["last_name"].sort_values()
# Out:
# 2        BC
# 3      BSDK
# 1     Chura
# 0    Pretty
# Name: last_name, dtype: object

# %% [markdown]
# ## Sorting on Index

# %%
# let's sort our data on last_name in descending order
data.sort_values(by="last_name", ascending=False, inplace=True)

# %%
data
# Out:
#   first_name last_name  age           city  salary
# 0      Alice    Pretty   25       New York   10000
# 1        Bob     Chura   32          Paris  120000
# 3      David      BSDK   47  San Francisco  105000
# 2    Charlie        BC   18         London  125000

# %%
# above cell output has random indexes we can sort index wise as well
data.sort_index(inplace=True)
data
# Now our data is sorted on index in ascending order
# Out:
#   first_name last_name  age           city  salary
# 0      Alice    Pretty   25       New York   10000
# 1        Bob     Chura   32          Paris  120000
# 2    Charlie        BC   18         London  125000
# 3      David      BSDK   47  San Francisco  105000

# %% [markdown]
# ## Let's start working on Stackoverflow data

# %%
df
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# ...                                                  ...
# 88878  Taught yourself a new language, framework, or ...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Taken an online course in programming or softw...
#
#                         OrgSize  \
# 0                           NaN
# 1                           NaN
# 2          100 to 499 employees
# 3          100 to 499 employees
# 4      10,000 or more employees
# ...                         ...
# 88878                       NaN
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                       NaN
#
#                                                  DevType YearsCode Age1stCode  \
# 0                                                    NaN         4         10
# 1      Developer, desktop or enterprise applications;...       NaN         17
# 2      Designer;Developer, back-end;Developer, front-...         3         22
# 3                                  Developer, full-stack         3         16
# 4      Academic researcher;Developer, desktop or ente...        16         14
# ...                                                  ...       ...        ...
# 88878                                                NaN       NaN        NaN
# 88879                                                NaN       NaN        NaN
# 88880                                                NaN       NaN        NaN
# 88881                                                NaN       NaN        NaN
# 88882                                                NaN         8         11
#
#            YearsCodePro           CareerSat                 JobSat  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                     1  Slightly satisfied     Slightly satisfied
# 3      Less than 1 year      Very satisfied     Slightly satisfied
# 4                     9   Very dissatisfied  Slightly dissatisfied
# ...                 ...                 ...                    ...
# 88878               NaN                 NaN                    NaN
# 88879               NaN                 NaN                    NaN
# 88880               NaN                 NaN                    NaN
# 88881               NaN                 NaN                    NaN
# 88882                 3                 NaN                    NaN
#
#                    MgrIdiot  MgrMoney   MgrWant  \
# 0                       NaN       NaN       NaN
# 1                       NaN       NaN       NaN
# 2      Not at all confident  Not sure  Not sure
# 3            Very confident        No  Not sure
# 4        Somewhat confident       Yes        No
# ...                     ...       ...       ...
# 88878                   NaN       NaN       NaN
# 88879                   NaN       NaN       NaN
# 88880                   NaN       NaN       NaN
# 88881                   NaN       NaN       NaN
# 88882                   NaN       NaN       NaN
#
#                                                  JobSeek  \
# 0                                                    NaN
# 1                        I am actively looking for a job
# 2      I’m not actively looking, but I am open to new...
# 3           I am not interested in new job opportunities
# 4           I am not interested in new job opportunities
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                LastHireDate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 88878                   NaN
# 88879                   NaN
# 88880                   NaN
# 88881                   NaN
# 88882                   NaN
#
#                                                  LastInt FizzBuzz  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                    Interview with people in peer roles       No
# 3      Write code by hand (e.g., on a whiteboard);Int...       No
# 4      Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88878                                                NaN      NaN
# 88879                                                NaN      NaN
# 88880                                                NaN      NaN
# 88881                                                NaN      NaN
# 88882                                                NaN      NaN
#
#                                               JobFactors  \
# 0                                                    NaN
# 1      Financial performance or funding status of the...
# 2      Languages, frameworks, and other technologies ...
# 3      Languages, frameworks, and other technologies ...
# 4      Industry that I'd be working in;Languages, fra...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 0                                                    NaN            NaN
# 1      Something else changed (education, award, medi...            NaN
# 2                       I was preparing for a job search            THB
# 3                       I was preparing for a job search            USD
# 4                       I was preparing for a job search            UAH
# ...                                                  ...            ...
# 88878                                                NaN            NaN
# 88879                                                NaN            NaN
# 88880                                                NaN            NaN
# 88881                                                NaN            NaN
# 88882                                                NaN            NaN
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                       NaN        NaN      NaN            NaN          NaN
# 1                       NaN        NaN      NaN            NaN          NaN
# 2                 Thai baht    23000.0  Monthly         8820.0         40.0
# 3      United States dollar    61000.0   Yearly        61000.0         80.0
# 4         Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                     ...        ...      ...            ...          ...
# 88878                   NaN        NaN      NaN            NaN          NaN
# 88879                   NaN        NaN      NaN            NaN          NaN
# 88880                   NaN        NaN      NaN            NaN          NaN
# 88881                   NaN        NaN      NaN            NaN          NaN
# 88882                   NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 0                                                    NaN
# 1                                                    NaN
# 2      There's no schedule or spec; I work on what se...
# 3      There's no schedule or spec; I work on what se...
# 4      There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                                            WorkChallenge  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Distracting work environment;Inadequate access...
# 3                                                    NaN
# 4      Being tasked with non-development work;Inadequ...
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 0                                   NaN     NaN                     NaN
# 1                                   NaN     NaN                     NaN
# 2      Less than once per month / Never    Home                 Average
# 3      Less than once per month / Never    Home  A little below average
# 4                 A few days each month  Office  A little above average
# ...                                 ...     ...                     ...
# 88878                               NaN     NaN                     NaN
# 88879                               NaN     NaN                     NaN
# 88880                               NaN     NaN                     NaN
# 88881                               NaN     NaN                     NaN
# 88882                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 0                                          NaN         NaN
# 1                                          NaN         NaN
# 2                                           No         NaN
# 3                                           No         NaN
# 4      Yes, because I see value in code review         NaN
# ...                                        ...         ...
# 88878                                      NaN         NaN
# 88879                                      NaN         NaN
# 88880                                      NaN         NaN
# 88881                                      NaN         NaN
# 88882                                      NaN         NaN
#
#                            UnitTests  \
# 0                                NaN
# 1                                NaN
# 2          No, but I think we should
# 3          No, but I think we should
# 4      Yes, it's part of our process
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                              PurchaseHow  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                               Not sure
# 3      Developers typically have the most influence o...
# 4                                               Not sure
# ...                                                  ...
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                NaN
#
#                         PurchaseWhat  \
# 0                                NaN
# 1                                NaN
# 2      I have little or no influence
# 3      I have little or no influence
# 4      I have little or no influence
# ...                              ...
# 88878                            NaN
# 88879                            NaN
# 88880                            NaN
# 88881                            NaN
# 88882                            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                   LanguageDesireNextYear  \
# 0        C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                            C++;HTML/CSS;JavaScript;SQL
# 2                                        Elixir;HTML/CSS
# 3                                    C;C#;JavaScript;SQL
# 4               HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                  ...
# 88878  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                      DatabaseWorkedWith  \
# 0                                                SQLite
# 1                                                   NaN
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4      Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                 ...
# 88878                                   Firebase;SQLite
# 88879                                               NaN
# 88880                                               NaN
# 88881                                               NaN
# 88882       DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                                   DatabaseDesireNextYear  \
# 0                                                  MySQL
# 1                                                  MySQL
# 2                                             PostgreSQL
# 3                                           MySQL;SQLite
# 4      Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                  ...
# 88878                              Firebase;MySQL;SQLite
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                        MariaDB;MySQL;Oracle;SQLite
#
#                       PlatformWorkedWith  \
# 0                          MacOS;Windows
# 1                                Windows
# 2                                    NaN
# 3                          Linux;Windows
# 4      Android;Linux;MacOS;Slack;Windows
# ...                                  ...
# 88878                              Linux
# 88879                                NaN
# 88880                                NaN
# 88881                                NaN
# 88882          iOS;Linux;MacOS;WordPress
#
#                                   PlatformDesireNextYear  \
# 0                                Android;Arduino;Windows
# 1                                                Windows
# 2                                                    NaN
# 3                                          Linux;Windows
# 4                  Android;Docker;Kubernetes;Linux;Slack
# ...                                                  ...
# 88878                        Google Cloud Platform;Linux
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                 WebFrameWorkedWith  \
# 0                                     Django;Flask
# 1                                           Django
# 2                                              NaN
# 3                                              NaN
# 4      Django;Express;Flask;jQuery;React.js;Spring
# ...                                            ...
# 88878                                       jQuery
# 88879                                          NaN
# 88880                                          NaN
# 88881                                          NaN
# 88882                       Django;jQuery;React.js
#
#              WebFrameDesireNextYear      MiscTechWorkedWith  \
# 0                      Flask;jQuery                 Node.js
# 1                            Django                     NaN
# 2                         Other(s):                     NaN
# 3                               NaN                    .NET
# 4      Flask;jQuery;React.js;Spring         Cordova;Node.js
# ...                             ...                     ...
# 88878                 jQuery;Vue.js                 Node.js
# 88879                           NaN                     NaN
# 88880                           NaN                     NaN
# 88881                           NaN                     NaN
# 88882                        Django  Unity 3D;Unreal Engine
#
#                          MiscTechDesireNextYear  \
# 0                                       Node.js
# 1                                           NaN
# 2                                           NaN
# 3                                          .NET
# 4      Apache Spark;Hadoop;Node.js;React Native
# ...                                         ...
# 88878       React Native;Unity 3D;Unreal Engine
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882                                       NaN
#
#                                               DevEnviron        OpSys  \
# 0                             IntelliJ;Notepad++;PyCharm      Windows
# 1                                           Atom;PyCharm      Windows
# 2                                 Vim;Visual Studio Code  Linux-based
# 3           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                                 IntelliJ;Notepad++;Vim  Linux-based
# ...                                                  ...          ...
# 88878              Atom;Visual Studio;Visual Studio Code      Windows
# 88879                                                NaN          NaN
# 88880                                                NaN          NaN
# 88881                                                NaN          NaN
# 88882  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                    Containers BlockchainOrg  \
# 0                     I do not use containers           NaN
# 1                     I do not use containers           NaN
# 2                     I do not use containers           NaN
# 3                     I do not use containers    Not at all
# 4      Outside of work, for personal projects    Not at all
# ...                                       ...           ...
# 88878                 I do not use containers           NaN
# 88879                                     NaN           NaN
# 88880                                     NaN           NaN
# 88881                                     NaN           NaN
# 88882                              Production           NaN
#
#                                             BlockchainIs BetterLife  \
# 0                                                    NaN        Yes
# 1      Useful across many domains and could change ma...        Yes
# 2                                                    NaN        Yes
# 3      Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                    NaN        Yes
# ...                                                  ...        ...
# 88878  Useful across many domains and could change ma...        Yes
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn SocialMedia  \
# 0      Fortunately, someone else has that title    Yes     Twitter
# 1                                           Yes    Yes   Instagram
# 2                                           Yes    Yes      Reddit
# 3                                          SIGH    Yes      Reddit
# 4                                      Also Yes    Yes    Facebook
# ...                                         ...    ...         ...
# 88878                                       Yes  What?     YouTube
# 88879                                       NaN    NaN         NaN
# 88880                                       NaN    NaN         NaN
# 88881                                       NaN    NaN         NaN
# 88882                                  Also Yes    Yes    WhatsApp
#
#                    Extraversion ScreenName        SOVisit1st  \
# 0                        Online   Username              2017
# 1                        Online   Username              2017
# 2      In real life (in person)   Username              2011
# 3      In real life (in person)   Username              2014
# 4      In real life (in person)   Username  I don't remember
# ...                         ...        ...               ...
# 88878                       NaN   Username  I don't remember
# 88879                       NaN        NaN               NaN
# 88880                       NaN        NaN               NaN
# 88881                       NaN        NaN               NaN
# 88882  In real life (in person)        NaN              2012
#
#                            SOVisitFreq  \
# 0      A few times per month or weekly
# 1                Daily or almost daily
# 2                 A few times per week
# 3                Daily or almost daily
# 4               Multiple times per day
# ...                                ...
# 88878             A few times per week
# 88879                              NaN
# 88880                              NaN
# 88881                              NaN
# 88882            Daily or almost daily
#
#                                                SOVisitTo  \
# 0      Find answers to specific questions;Learn how t...
# 1      Find answers to specific questions;Learn how t...
# 2      Find answers to specific questions;Learn how t...
# 3      Find answers to specific questions;Pass the ti...
# 4                     Find answers to specific questions
# ...                                                  ...
# 88878  Find answers to specific questions;Learn how t...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                         SOTimeSaved  \
# 0               3-5 times per week      Stack Overflow was much faster
# 1               3-5 times per week      Stack Overflow was much faster
# 2              6-10 times per week            They were about the same
# 3               1-2 times per week      Stack Overflow was much faster
# 4      More than 10 times per week      Stack Overflow was much faster
# ...                            ...                                 ...
# 88878           3-5 times per week  Stack Overflow was slightly faster
# 88879                          NaN                                 NaN
# 88880                          NaN                                 NaN
# 88881                          NaN                                 NaN
# 88882          6-10 times per week      Stack Overflow was much faster
#
#        SOHowMuchTime SOAccount  \
# 0      31-60 minutes        No
# 1      11-30 minutes       Yes
# 2                NaN       Yes
# 3      31-60 minutes       Yes
# 4                NaN       Yes
# ...              ...       ...
# 88878  11-30 minutes       Yes
# 88879            NaN       NaN
# 88880            NaN       NaN
# 88881            NaN       NaN
# 88882  11-30 minutes       Yes
#
#                                               SOPartFreq  \
# 0                                                    NaN
# 1                        A few times per month or weekly
# 2                    Less than once per month or monthly
# 3                    Less than once per month or monthly
# 4                        A few times per month or weekly
# ...                                                  ...
# 88878  I have never participated in Q&A on Stack Over...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                    A few times per month or weekly
#
#                                                   SOJobs  \
# 0      No, I didn't know that Stack Overflow had a jo...
# 1      No, I knew that Stack Overflow had a job board...
# 2                                                    Yes
# 3                                                    Yes
# 4      No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 88878  No, I knew that Stack Overflow had a job board...
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                                                Yes
#
#                                                 EntTeams           SOComm  \
# 0                    No, and I don't know what those are          Neutral
# 1                    No, and I don't know what those are    Yes, somewhat
# 2      No, I've heard of them, but I am not part of a...          Neutral
# 3                    No, and I don't know what those are   No, not really
# 4      No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                  ...              ...
# 88878  No, I've heard of them, but I am not part of a...   No, not at all
# 88879                                                NaN              NaN
# 88880                                                NaN              NaN
# 88881                                                NaN              NaN
# 88882  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
# sorting on country column with inplace=True
df.sort_values(by="Country",inplace=True)

# %%
df.head(10)
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 39018       39258          I am a developer by profession      Yes
# 62723       63129          I am a developer by profession      Yes
# 85185       85715          I am a developer by profession       No
# 50437       50767          I am a developer by profession       No
# 88340        2782                                     NaN      Yes
# 88735       63019                                     NaN       No
# 6391         6417  I am a student who is learning to code      Yes
# 39754       40000  I am a student who is learning to code      Yes
# 88181       88731             I code primarily as a hobby      Yes
# 48122       48436          I am a developer by profession       No
#
#                                              OpenSourcer  \
# 39018                            Less than once per year
# 62723                                              Never
# 85185                            Less than once per year
# 50437                            Less than once per year
# 88340                            Less than once per year
# 88735                         Once a month or more often
# 6391                                               Never
# 39754                         Once a month or more often
# 88181  Less than once a month but more than once per ...
# 48122                         Once a month or more often
#
#                                               OpenSource  \
# 39018  OSS is, on average, of LOWER quality than prop...
# 62723  OSS is, on average, of HIGHER quality than pro...
# 85185  The quality of OSS and closed source software ...
# 50437                                                NaN
# 88340  OSS is, on average, of HIGHER quality than pro...
# 88735  OSS is, on average, of LOWER quality than prop...
# 6391   OSS is, on average, of HIGHER quality than pro...
# 39754  The quality of OSS and closed source software ...
# 88181  OSS is, on average, of LOWER quality than prop...
# 48122  The quality of OSS and closed source software ...
#
#                                               Employment      Country  \
# 39018                                 Employed full-time  Afghanistan
# 62723                                 Employed full-time  Afghanistan
# 85185                                 Employed full-time  Afghanistan
# 50437  Independent contractor, freelancer, or self-em...  Afghanistan
# 88340                                                NaN  Afghanistan
# 88735                                                NaN  Afghanistan
# 6391                                  Employed full-time  Afghanistan
# 39754             Not employed, and not looking for work  Afghanistan
# 88181                                                NaN  Afghanistan
# 48122                                 Employed full-time  Afghanistan
#
#               Student                                            EdLevel  \
# 39018              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62723  Yes, full-time             I never completed any formal education
# 85185              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50437  Yes, part-time                                   Associate degree
# 88340              No                                                NaN
# 88735              No  Some college/university study without earning ...
# 6391   Yes, part-time  Secondary school (e.g. American high school, G...
# 39754  Yes, full-time  Secondary school (e.g. American high school, G...
# 88181              No                          Primary/elementary school
# 48122  Yes, part-time  Secondary school (e.g. American high school, G...
#
#                                           UndergradMajor  \
# 39018  Computer science, computer engineering, or sof...
# 62723                                                NaN
# 85185  Information systems, information technology, o...
# 50437  A health science (ex. nursing, pharmacy, radio...
# 88340                           I never declared a major
# 88735  A social science (ex. anthropology, psychology...
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                                NaN
# 48122                                                NaN
#
#                                                 EduOther  \
# 39018  Taken an online course in programming or softw...
# 62723  Taken an online course in programming or softw...
# 85185  Received on-the-job training in software devel...
# 50437  Completed an industry certification program (e...
# 88340  Taken an online course in programming or softw...
# 88735                        Participated in a hackathon
# 6391   Taught yourself a new language, framework, or ...
# 39754  Taught yourself a new language, framework, or ...
# 88181  Taken a part-time in-person course in programm...
# 48122  Taken a part-time in-person course in programm...
#
#                                                  OrgSize  \
# 39018                               100 to 499 employees
# 62723  Just me - I am a freelancer, sole proprietor, ...
# 85185                                                NaN
# 50437                           1,000 to 4,999 employees
# 88340                                                NaN
# 88735                                                NaN
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                                NaN
# 48122                                 10 to 19 employees
#
#                                                  DevType         YearsCode  \
# 39018  Database administrator;Designer;Developer, bac...                 2
# 62723                                                NaN  Less than 1 year
# 85185                                Developer, back-end                 8
# 50437  Developer, desktop or enterprise applications;...               NaN
# 88340                                                NaN                 3
# 88735                                                NaN                 2
# 6391                                             Student                 1
# 39754                                                NaN                 3
# 88181                                                NaN  Less than 1 year
# 48122  Database administrator;Designer;Developer, bac...                 2
#
#                  Age1stCode      YearsCodePro  \
# 39018                    22                 1
# 62723  Younger than 5 years                 1
# 85185                    20                 4
# 50437                   NaN               NaN
# 88340  Younger than 5 years  Less than 1 year
# 88735                    22                17
# 6391                     14               NaN
# 39754                    10               NaN
# 88181                    17               NaN
# 48122                    20                 1
#
#                                 CareerSat                 JobSat  \
# 39018                      Very satisfied         Very satisfied
# 62723                   Very dissatisfied      Very dissatisfied
# 85185                      Very satisfied     Slightly satisfied
# 50437  Neither satisfied nor dissatisfied      Very dissatisfied
# 88340                                 NaN                    NaN
# 88735                                 NaN                    NaN
# 6391                                  NaN                    NaN
# 39754                                 NaN                    NaN
# 88181                                 NaN                    NaN
# 48122               Slightly dissatisfied  Slightly dissatisfied
#
#                  MgrIdiot MgrMoney MgrWant  \
# 39018      Very confident       No     Yes
# 62723      Very confident      Yes     Yes
# 85185  Somewhat confident      Yes     Yes
# 50437                 NaN      NaN     NaN
# 88340                 NaN      NaN     NaN
# 88735                 NaN      NaN     NaN
# 6391                  NaN      NaN     NaN
# 39754                 NaN      NaN     NaN
# 88181                 NaN      NaN     NaN
# 48122      Very confident      Yes     Yes
#
#                                                  JobSeek  \
# 39018  I’m not actively looking, but I am open to new...
# 62723                    I am actively looking for a job
# 85185  I’m not actively looking, but I am open to new...
# 50437  I’m not actively looking, but I am open to new...
# 88340                                                NaN
# 88735                                                NaN
# 6391                     I am actively looking for a job
# 39754                                                NaN
# 88181                                                NaN
# 48122  I’m not actively looking, but I am open to new...
#
#                LastHireDate  \
# 39018         1-2 years ago
# 62723  I've never had a job
# 85185         1-2 years ago
# 50437                   NaN
# 88340                   NaN
# 88735                   NaN
# 6391   I've never had a job
# 39754                   NaN
# 88181                   NaN
# 48122  Less than a year ago
#
#                                                  LastInt FizzBuzz  \
# 39018  Write code by hand (e.g., on a whiteboard);Int...       No
# 62723                                     Write any code      Yes
# 85185  Write code by hand (e.g., on a whiteboard);Int...       No
# 50437                                                NaN      NaN
# 88340                                                NaN      NaN
# 88735                                                NaN      NaN
# 6391                                                 NaN      NaN
# 39754                                                NaN      NaN
# 88181                                                NaN      NaN
# 48122  Interview with people in peer roles;Interview ...       No
#
#                                               JobFactors  \
# 39018  Languages, frameworks, and other technologies ...
# 62723  How widely used or impactful my work output wo...
# 85185  Financial performance or funding status of the...
# 50437                                                NaN
# 88340                                                NaN
# 88735                                                NaN
# 6391   Languages, frameworks, and other technologies ...
# 39754                                                NaN
# 88181                                                NaN
# 48122  Financial performance or funding status of the...
#
#                                             ResumeUpdate CurrencySymbol  \
# 39018  Something else changed (education, award, medi...            AFN
# 62723  I had a negative experience or interaction at ...            AED
# 85185                   I was preparing for a job search            AFN
# 50437                                                NaN            AMD
# 88340                                                NaN            NaN
# 88735                                                NaN            NaN
# 6391                                                 NaN            NaN
# 39754                                                NaN            NaN
# 88181                                                NaN            NaN
# 48122  I heard about a job opportunity (from a recrui...            AFN
#
#                       CurrencyDesc    CompTotal CompFreq  ConvertedComp  \
# 39018               Afghan afghani     120000.0  Monthly        19152.0
# 62723  United Arab Emirates dirham  648838511.0  Monthly      1000000.0
# 85185               Afghan afghani          NaN  Monthly            NaN
# 50437                Armenian dram          NaN      NaN            NaN
# 88340                          NaN          NaN      NaN            NaN
# 88735                          NaN          NaN      NaN            NaN
# 6391                           NaN          NaN      NaN            NaN
# 39754                          NaN          NaN      NaN            NaN
# 88181                          NaN          NaN      NaN            NaN
# 48122               Afghan afghani      28000.0  Monthly         4464.0
#
#        WorkWeekHrs                                           WorkPlan  \
# 39018         49.0  There is a schedule and/or spec (made by me or...
# 62723        168.0  There is a schedule and/or spec (made by me or...
# 85185         48.0  There is a schedule and/or spec (made by me or...
# 50437          NaN                                                NaN
# 88340          NaN                                                NaN
# 88735          NaN                                                NaN
# 6391           NaN                                                NaN
# 39754          NaN                                                NaN
# 88181          NaN                                                NaN
# 48122         45.0  There's no schedule or spec; I work on what se...
#
#                                            WorkChallenge  \
# 39018  Not enough people for the workload;Time spent ...
# 62723             Being tasked with non-development work
# 85185  Distracting work environment;Non-work commitme...
# 50437                                                NaN
# 88340                                                NaN
# 88735                                                NaN
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                                NaN
# 48122  Inadequate access to necessary tools;Lack of s...
#
#                              WorkRemote  \
# 39018  Less than once per month / Never
# 62723                  It's complicated
# 85185  Less than once per month / Never
# 50437                               NaN
# 88340                               NaN
# 88735                               NaN
# 6391                                NaN
# 39754                               NaN
# 88181                               NaN
# 48122                  It's complicated
#
#                                               WorkLoc                  ImpSyn  \
# 39018                                          Office       Far above average
# 62723  Other place, such as a coworking space or cafe       Far below average
# 85185                                          Office  A little above average
# 50437                                             NaN                     NaN
# 88340                                             NaN                     NaN
# 88735                                             NaN                     NaN
# 6391                                              NaN                     NaN
# 39754                                             NaN                     NaN
# 88181                                             NaN                     NaN
# 48122                                          Office  A little above average
#
#                                        CodeRev  CodeRevHrs  \
# 39018  Yes, because I see value in code review        10.0
# 62723                                       No         NaN
# 85185  Yes, because I see value in code review         5.0
# 50437                                      NaN         NaN
# 88340                                      NaN         NaN
# 88735                                      NaN         NaN
# 6391                                       NaN         NaN
# 39754                                      NaN         NaN
# 88181                                      NaN         NaN
# 48122         Yes, because I was told to do so        10.0
#
#                                                UnitTests  \
# 39018  Yes, it's not part of our process but the deve...
# 62723                                                NaN
# 85185  Yes, it's not part of our process but the deve...
# 50437                                                NaN
# 88340                                                NaN
# 88735                                                NaN
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                                NaN
# 48122                          No, but I think we should
#
#                                              PurchaseHow  \
# 39018  Developers typically have the most influence o...
# 62723                                                NaN
# 85185  Developers and management have nearly equal in...
# 50437                                                NaN
# 88340                                                NaN
# 88735                                                NaN
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                                NaN
# 48122                                           Not sure
#
#                         PurchaseWhat  \
# 39018          I have some influence
# 62723                            NaN
# 85185          I have some influence
# 50437                            NaN
# 88340                            NaN
# 88735                            NaN
# 6391                             NaN
# 39754                            NaN
# 88181                            NaN
# 48122  I have little or no influence
#
#                              LanguageWorkedWith  \
# 39018    HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 62723  Assembly;Bash/Shell/PowerShell;Other(s):
# 85185        HTML/CSS;JavaScript;PHP;TypeScript
# 50437                                       NaN
# 88340                                  HTML/CSS
# 88735                                  Assembly
# 6391                                       Java
# 39754                                    Python
# 88181   HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 48122                C#;HTML/CSS;JavaScript;PHP
#
#                        LanguageDesireNextYear  \
# 39018       C#;Dart;JavaScript;SQL;TypeScript
# 62723        Bash/Shell/PowerShell;TypeScript
# 85185  HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 50437                                     NaN
# 88340                                     NaN
# 88735                                Assembly
# 6391                Bash/Shell/PowerShell;C++
# 39754                                      C#
# 88181                                     NaN
# 48122          HTML/CSS;JavaScript;PHP;Python
#
#                      DatabaseWorkedWith  \
# 39018  MariaDB;MongoDB;MySQL;PostgreSQL
# 62723                             MySQL
# 85185             MariaDB;MongoDB;MySQL
# 50437                               NaN
# 88340                               NaN
# 88735                         Other(s):
# 6391                                NaN
# 39754                            SQLite
# 88181                             MySQL
# 48122                    Firebase;MySQL
#
#                                   DatabaseDesireNextYear  \
# 39018           Couchbase;Firebase;MariaDB;MongoDB;Redis
# 62723                                              MySQL
# 85185  MariaDB;MongoDB;Microsoft SQL Server;MySQL;Ora...
# 50437                                                NaN
# 88340                                                NaN
# 88735                                          Other(s):
# 6391                                                 NaN
# 39754             Microsoft SQL Server;PostgreSQL;SQLite
# 88181                                                NaN
# 48122                                     Firebase;MySQL
#
#                             PlatformWorkedWith  \
# 39018      Android;AWS;Linux;Windows;WordPress
# 62723  Android;iOS;Windows;WordPress;Other(s):
# 85185                  Linux;Windows;WordPress
# 50437                                      NaN
# 88340                                  Windows
# 88735                                Other(s):
# 6391                                     Linux
# 39754                                      NaN
# 88181                                      NaN
# 48122                Android;Windows;WordPress
#
#                                   PlatformDesireNextYear  \
# 39018  Android;AWS;Docker;Heroku;iOS;Linux;Raspberry ...
# 62723            Android;iOS;Windows;WordPress;Other(s):
# 85185                          Android;AWS;Linux;Windows
# 50437                                                NaN
# 88340                                                NaN
# 88735                                          Other(s):
# 6391                                               Linux
# 39754                     Android;iOS;Linux;Raspberry Pi
# 88181                                                NaN
# 48122                          Android;Windows;WordPress
#
#                                       WebFrameWorkedWith  \
# 39018          Angular/Angular.js;Drupal;Express;Laravel
# 62723  Angular/Angular.js;Express;jQuery;Laravel;Othe...
# 85185                                     jQuery;Laravel
# 50437                                                NaN
# 88340                                                NaN
# 88735                                          Other(s):
# 6391                                                 NaN
# 39754                                                NaN
# 88181                                             Django
# 48122  Angular/Angular.js;jQuery;Laravel;React.js;Vue.js
#
#                                   WebFrameDesireNextYear  \
# 39018                  Angular/Angular.js;Drupal;Express
# 62723  Angular/Angular.js;Express;jQuery;Laravel;Othe...
# 85185                                    Express;Laravel
# 50437                                                NaN
# 88340                                                NaN
# 88735                                          Other(s):
# 6391                                                 NaN
# 39754                               jQuery;Ruby on Rails
# 88181                                                NaN
# 48122                  Angular/Angular.js;jQuery;Laravel
#
#                        MiscTechWorkedWith          MiscTechDesireNextYear  \
# 39018                     Cordova;Node.js                  Hadoop;Node.js
# 62723  Ansible;Apache Spark;Torch/PyTorch      Apache Spark;Torch/PyTorch
# 85185                             Node.js  .NET Core;Node.js;React Native
# 50437                                 NaN                             NaN
# 88340                                 NaN                             NaN
# 88735                           Other(s):                       Other(s):
# 6391                                  NaN                             NaN
# 39754    CryEngine;Unity 3D;Unreal Engine                            .NET
# 88181                                 NaN                             NaN
# 48122      .NET Core;Node.js;React Native                         Node.js
#
#                                               DevEnviron        OpSys  \
# 39018          Notepad++;PHPStorm;Vim;Visual Studio Code  Linux-based
# 62723  Android Studio;Atom;Coda;Eclipse;Emacs;IPython...      Windows
# 85185  Notepad++;PHPStorm;Sublime Text;Visual Studio ...      Windows
# 50437                                                NaN          NaN
# 88340                                                NaN      Windows
# 88735                                     Android Studio        MacOS
# 6391                                        NetBeans;Vim  Linux-based
# 39754                                          Notepad++      Windows
# 88181  Atom;Eclipse;NetBeans;Notepad++;PyCharm;Visual...      Windows
# 48122      Sublime Text;Visual Studio;Visual Studio Code      Windows
#
#                                    Containers  \
# 39018                              Production
# 62723  Outside of work, for personal projects
# 85185                 I do not use containers
# 50437                                     NaN
# 88340                 I do not use containers
# 88735                                     NaN
# 6391                  I do not use containers
# 39754  Outside of work, for personal projects
# 88181                                     NaN
# 48122                             Development
#
#                                            BlockchainOrg  \
# 39018                                                NaN
# 62723  Accepting Bitcoin or other coins and tokens as...
# 85185                                                NaN
# 50437                                                NaN
# 88340                                                NaN
# 88735                                                NaN
# 6391                                          Not at all
# 39754                                                NaN
# 88181                                                NaN
# 48122                                                NaN
#
#                                             BlockchainIs BetterLife  \
# 39018                                                NaN        Yes
# 62723  Useful across many domains and could change ma...        Yes
# 85185                                                NaN         No
# 50437                                                NaN        NaN
# 88340                                      A passing fad        Yes
# 88735                                                NaN         No
# 6391                                                 NaN         No
# 39754  Useful across many domains and could change ma...        Yes
# 88181                                                NaN        Yes
# 48122                                                NaN        Yes
#
#                                        ITperson  OffOn  \
# 39018                                       Yes     No
# 62723                                       Yes    Yes
# 85185                                       Yes    Yes
# 50437                                       NaN    NaN
# 88340                                      SIGH  What?
# 88735                                      SIGH  What?
# 6391                                        Yes    Yes
# 39754  Fortunately, someone else has that title    Yes
# 88181                                      SIGH    Yes
# 48122  Fortunately, someone else has that title    Yes
#
#                     SocialMedia              Extraversion ScreenName  \
# 39018                  Facebook                    Online      Login
# 62723  I don't use social media                    Online     UserID
# 85185                  Facebook                    Online   Username
# 50437                       NaN                       NaN        NaN
# 88340  I don't use social media                   Neither        NaN
# 88735                  LinkedIn                   Neither      Login
# 6391                   Facebook  In real life (in person)   Username
# 39754                  WhatsApp  In real life (in person)   Username
# 88181                   YouTube                    Online     UserID
# 48122                  Facebook                    Online   Username
#
#              SOVisit1st                                        SOVisitFreq  \
# 39018              2016                               A few times per week
# 62723               NaN  I have never visited Stack Overflow (before to...
# 85185  I don't remember                             Multiple times per day
# 50437               NaN                                                NaN
# 88340  I don't remember                    A few times per month or weekly
# 88735               NaN                               A few times per week
# 6391               2016                               A few times per week
# 39754              2016                    A few times per month or weekly
# 88181              2017                               A few times per week
# 48122              2017                             Multiple times per day
#
#                                                SOVisitTo  \
# 39018  Find answers to specific questions;Learn how t...
# 62723                 Find answers to specific questions
# 85185                 Find answers to specific questions
# 50437                                                NaN
# 88340                              Pass the time / relax
# 88735  Learn how to do things I didn’t necessarily lo...
# 6391   Find answers to specific questions;Learn how t...
# 39754  Find answers to specific questions;Learn how t...
# 88181  Find answers to specific questions;Get a sense...
# 48122  Find answers to specific questions;Learn how t...
#
#                   SOFindAnswer                         SOTimeSaved  \
# 39018       1-2 times per week      Stack Overflow was much faster
# 62723  Less than once per week      Stack Overflow was much faster
# 85185       3-5 times per week      Stack Overflow was much faster
# 50437                      NaN                                 NaN
# 88340  Less than once per week            They were about the same
# 88735                      NaN  The other resource was much faster
# 6391        1-2 times per week  Stack Overflow was slightly faster
# 39754       1-2 times per week      Stack Overflow was much faster
# 88181       3-5 times per week      Stack Overflow was much faster
# 48122       1-2 times per week      Stack Overflow was much faster
#
#        SOHowMuchTime                  SOAccount  \
# 39018   0-10 minutes                        Yes
# 62723   0-10 minutes                        NaN
# 85185  11-30 minutes                        Yes
# 50437            NaN                        NaN
# 88340            NaN                        Yes
# 88735    60+ minutes  Not sure / can't remember
# 6391   11-30 minutes                         No
# 39754   0-10 minutes                        Yes
# 88181  31-60 minutes  Not sure / can't remember
# 48122    60+ minutes                        Yes
#
#                                               SOPartFreq  \
# 39018                Less than once per month or monthly
# 62723                                                NaN
# 85185  I have never participated in Q&A on Stack Over...
# 50437                                                NaN
# 88340  I have never participated in Q&A on Stack Over...
# 88735                                                NaN
# 6391                                                 NaN
# 39754  I have never participated in Q&A on Stack Over...
# 88181                                                NaN
# 48122                               A few times per week
#
#                                                   SOJobs  \
# 39018                                                Yes
# 62723  No, I didn't know that Stack Overflow had a jo...
# 85185  No, I knew that Stack Overflow had a job board...
# 50437                                                NaN
# 88340  No, I knew that Stack Overflow had a job board...
# 88735                                                Yes
# 6391   No, I knew that Stack Overflow had a job board...
# 39754                                                Yes
# 88181  No, I knew that Stack Overflow had a job board...
# 48122                                                Yes
#
#                                                 EntTeams           SOComm  \
# 39018                                                NaN    Yes, somewhat
# 62723                                                NaN   No, not at all
# 85185                No, and I don't know what those are         Not sure
# 50437                                                NaN              NaN
# 88340                No, and I don't know what those are         Not sure
# 88735                                                Yes         Not sure
# 6391   No, I've heard of them, but I am not part of a...          Neutral
# 39754  No, I've heard of them, but I am not part of a...          Neutral
# 88181                No, and I don't know what those are   No, not really
# 48122                No, and I don't know what those are  Yes, definitely
#
#                                            WelcomeChange  \
# 39018                                                NaN
# 62723                                                NaN
# 85185           Somewhat less welcome now than last year
# 50437                                                NaN
# 88340            Just as welcome now as I felt last year
# 88735  Not applicable - I did not use Stack Overflow ...
# 6391             Just as welcome now as I felt last year
# 39754            Just as welcome now as I felt last year
# 88181            Just as welcome now as I felt last year
# 48122              A lot more welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 39018  Tech articles written by other developers;Indu...  26.0    Man    No
# 62723          Tech articles written by other developers   NaN    NaN   NaN
# 85185  Tech articles written by other developers;Indu...  28.0    Man    No
# 50437                                                NaN   NaN    NaN   NaN
# 88340                                                NaN  60.0    Man   NaN
# 88735       Courses on technologies you're interested in   NaN    Man   NaN
# 6391           Tech articles written by other developers   NaN    NaN   NaN
# 39754  Tech articles written by other developers;Indu...   NaN    NaN    No
# 88181  Tech articles written by other developers;Cour...   NaN    Man    No
# 48122  Industry news about technologies you're intere...  24.0    Man    No
#
#                      Sexuality               Ethnicity Dependents  \
# 39018  Straight / Heterosexual  East Asian;South Asian        Yes
# 62723                      NaN                     NaN        Yes
# 85185                      NaN                     NaN        Yes
# 50437                      NaN                     NaN        NaN
# 88340                      NaN                     NaN        NaN
# 88735                      NaN          Middle Eastern         No
# 6391   Straight / Heterosexual          Middle Eastern        NaN
# 39754                      NaN                     NaN        NaN
# 88181                      NaN                     NaN         No
# 48122                      NaN             South Asian         No
#
#                 SurveyLength                  SurveyEase
# 39018               Too long                        Easy
# 62723              Too short                        Easy
# 85185               Too long  Neither easy nor difficult
# 50437                    NaN                         NaN
# 88340  Appropriate in length                        Easy
# 88735              Too short  Neither easy nor difficult
# 6391   Appropriate in length  Neither easy nor difficult
# 39754  Appropriate in length                        Easy
# 88181  Appropriate in length                        Easy
# 48122               Too long  Neither easy nor difficult

# %%
df["Country"].head(10)
# Out:
# 39018    Afghanistan
# 62723    Afghanistan
# 85185    Afghanistan
# 50437    Afghanistan
# 88340    Afghanistan
# 88735    Afghanistan
# 6391     Afghanistan
# 39754    Afghanistan
# 88181    Afghanistan
# 48122    Afghanistan
# Name: Country, dtype: object

# %%
# Sorting on "Country" column and "ConvertedComp" which is dollar converted salary
df.sort_values(by=["Country","ConvertedComp"],ascending=[True,False], inplace=True)

# %%
df[["Country","ConvertedComp"]].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 26189  Afghanistan            NaN
# 86394  Afghanistan            NaN
# 85293  Afghanistan            NaN
# 7323   Afghanistan            NaN
# 86551  Afghanistan            NaN
# 58390  Afghanistan            NaN
# 73920  Afghanistan            NaN
# 28877  Afghanistan            NaN
# 51525  Afghanistan            NaN
# 45562  Afghanistan            NaN
# 46807  Afghanistan            NaN
# 44123  Afghanistan            NaN
# 80423  Afghanistan            NaN
# 59184  Afghanistan            NaN
# 60185  Afghanistan            NaN
# 37571  Afghanistan            NaN
# 42832  Afghanistan            NaN
# 12253  Afghanistan            NaN
# 61770  Afghanistan            NaN
# 38075      Albania       187668.0
# 3771       Albania       114550.0
# 9230       Albania        74474.0
# 6688       Albania        60000.0
# 10257      Albania        57300.0
# 65859      Albania        41244.0

# %% [markdown]
# # Getting number of largest values from series
# For this purpose we use nlargest() function

# %%
# we will get the 750 largest salaries
df["ConvertedComp"].nlargest(750)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
#            ...
# 48179    1800000.0
# 57795    1800000.0
# 72568    1800000.0
# 70575    1800000.0
# 35725    1800000.0
# Name: ConvertedComp, Length: 750, dtype: float64

# %% [markdown]
# ## Getting number of largest values from dataframe
# For this purpose we use nlargest() function

# %%
df.nlargest(750, "ConvertedComp")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# ...           ...                                                ...      ...
# 48179       48494  I am not primarily a developer, but I write co...       No
# 57795       58163                     I am a developer by profession      Yes
# 72568       73026                     I am a developer by profession      Yes
# 70575       71024                     I am a developer by profession      Yes
# 35725       35947                     I am a developer by profession       No
#
#                                              OpenSourcer  \
# 25833                            Less than once per year
# 87353                            Less than once per year
# 21895                                              Never
# 28080                         Once a month or more often
# 72274  Less than once a month but more than once per ...
# ...                                                  ...
# 48179                                              Never
# 57795                                              Never
# 72568  Less than once a month but more than once per ...
# 70575  Less than once a month but more than once per ...
# 35725                                              Never
#
#                                               OpenSource  \
# 25833  OSS is, on average, of HIGHER quality than pro...
# 87353  The quality of OSS and closed source software ...
# 21895  The quality of OSS and closed source software ...
# 28080  OSS is, on average, of HIGHER quality than pro...
# 72274  OSS is, on average, of LOWER quality than prop...
# ...                                                  ...
# 48179  OSS is, on average, of HIGHER quality than pro...
# 57795  OSS is, on average, of HIGHER quality than pro...
# 72568  OSS is, on average, of HIGHER quality than pro...
# 70575  The quality of OSS and closed source software ...
# 35725  OSS is, on average, of LOWER quality than prop...
#
#                                               Employment        Country  \
# 25833                                 Employed full-time         Canada
# 87353                                 Employed full-time        Germany
# 21895                                 Employed full-time          India
# 28080  Independent contractor, freelancer, or self-em...          India
# 72274                                                NaN          India
# ...                                                  ...            ...
# 48179                                 Employed full-time  United States
# 57795                                 Employed full-time  United States
# 72568                                 Employed full-time  United States
# 70575                                 Employed full-time  United States
# 35725                                 Employed full-time  United States
#
#               Student                                      EdLevel  \
# 25833              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87353              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 21895              No           Professional degree (JD, MD, etc.)
# 28080              No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 72274  Yes, full-time     Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                          ...
# 48179              No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 57795              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 72568              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 70575              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 35725              No     Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  \
# 25833  Computer science, computer engineering, or sof...
# 87353  Computer science, computer engineering, or sof...
# 21895  A natural science (ex. biology, chemistry, phy...
# 28080  Computer science, computer engineering, or sof...
# 72274  Computer science, computer engineering, or sof...
# ...                                                  ...
# 48179  Information systems, information technology, o...
# 57795  Computer science, computer engineering, or sof...
# 72568  Computer science, computer engineering, or sof...
# 70575  Computer science, computer engineering, or sof...
# 35725  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 25833  Received on-the-job training in software devel...
# 87353  Taken an online course in programming or softw...
# 21895  Taken an online course in programming or softw...
# 28080  Taken an online course in programming or softw...
# 72274                Contributed to open source software
# ...                                                  ...
# 48179  Taken a part-time in-person course in programm...
# 57795  Taught yourself a new language, framework, or ...
# 72568  Taken an online course in programming or softw...
# 70575  Received on-the-job training in software devel...
# 35725  Taught yourself a new language, framework, or ...
#
#                         OrgSize  \
# 25833  10,000 or more employees
# 87353             2-9 employees
# 21895             2-9 employees
# 28080             2-9 employees
# 72274                       NaN
# ...                         ...
# 48179  10,000 or more employees
# 57795        20 to 99 employees
# 72568  10,000 or more employees
# 70575        10 to 19 employees
# 35725  10,000 or more employees
#
#                                                  DevType YearsCode Age1stCode  \
# 25833                              Developer, full-stack         8         16
# 87353                              Developer, full-stack         9         17
# 21895  Academic researcher;Data scientist or machine ...         3         26
# 28080  Developer, back-end;Developer, full-stack;Deve...        25          9
# 72274                                                NaN         4         20
# ...                                                  ...       ...        ...
# 48179  Developer, QA or test;DevOps specialist;Engine...        27         19
# 57795  Developer, back-end;Developer, full-stack;Engi...        21         13
# 72568  Developer, desktop or enterprise applications;...        10         16
# 70575                              Developer, full-stack        15         11
# 35725                              Developer, full-stack         4         19
#
#            YearsCodePro                           CareerSat  \
# 25833                 2                      Very satisfied
# 87353                 8                      Very satisfied
# 21895                 3                      Very satisfied
# 28080                14  Neither satisfied nor dissatisfied
# 72274                 5                  Slightly satisfied
# ...                 ...                                 ...
# 48179                27                      Very satisfied
# 57795                17                      Very satisfied
# 72568                 6                      Very satisfied
# 70575                 4                  Slightly satisfied
# 35725  Less than 1 year                  Slightly satisfied
#
#                                    JobSat            MgrIdiot  MgrMoney  \
# 25833                      Very satisfied  Somewhat confident        No
# 87353                      Very satisfied  Somewhat confident        No
# 21895                      Very satisfied                 NaN       NaN
# 28080  Neither satisfied nor dissatisfied                 NaN       NaN
# 72274                  Slightly satisfied                 NaN       NaN
# ...                                   ...                 ...       ...
# 48179                      Very satisfied      Very confident       Yes
# 57795                      Very satisfied                 NaN       NaN
# 72568                      Very satisfied  Somewhat confident       Yes
# 70575                      Very satisfied      Very confident  Not sure
# 35725                  Slightly satisfied      Very confident        No
#
#                       MgrWant  \
# 25833                      No
# 87353  I am already a manager
# 21895                     NaN
# 28080                     NaN
# 72274                     NaN
# ...                       ...
# 48179                     Yes
# 57795                     NaN
# 72568                Not sure
# 70575                Not sure
# 35725                      No
#
#                                                  JobSeek  \
# 25833  I’m not actively looking, but I am open to new...
# 87353       I am not interested in new job opportunities
# 21895       I am not interested in new job opportunities
# 28080  I’m not actively looking, but I am open to new...
# 72274                    I am actively looking for a job
# ...                                                  ...
# 48179  I’m not actively looking, but I am open to new...
# 57795       I am not interested in new job opportunities
# 72568  I’m not actively looking, but I am open to new...
# 70575       I am not interested in new job opportunities
# 35725       I am not interested in new job opportunities
#
#                 LastHireDate  \
# 25833          3-4 years ago
# 87353  More than 4 years ago
# 21895          3-4 years ago
# 28080          1-2 years ago
# 72274  More than 4 years ago
# ...                      ...
# 48179  More than 4 years ago
# 57795          1-2 years ago
# 72568          3-4 years ago
# 70575   Less than a year ago
# 35725   Less than a year ago
#
#                                                  LastInt FizzBuzz  \
# 25833  Solve a brain-teaser style puzzle;Interview wi...       No
# 87353  Write any code;Interview with people in senior...       No
# 21895  Write code by hand (e.g., on a whiteboard);Com...       No
# 28080  Interview with people in peer roles;Interview ...      Yes
# 72274                                     Write any code       No
# ...                                                  ...      ...
# 48179  Interview with people in peer roles;Interview ...       No
# 57795  Interview with people in peer roles;Interview ...       No
# 72568  Write any code;Write code by hand (e.g., on a ...      Yes
# 70575  Write any code;Interview with people in peer r...       No
# 35725  Write any code;Interview with people in peer r...       No
#
#                                               JobFactors  \
# 25833  Remote work options;Opportunities for professi...
# 87353  Office environment or company culture;Diversit...
# 21895  Financial performance or funding status of the...
# 28080  Financial performance or funding status of the...
# 72274  Remote work options;Opportunities for professi...
# ...                                                  ...
# 48179  Industry that I'd be working in;Opportunities ...
# 57795  Industry that I'd be working in;Office environ...
# 72568  Industry that I'd be working in;Office environ...
# 70575  Specific department or team I'd be working on;...
# 35725  Specific department or team I'd be working on;...
#
#                                             ResumeUpdate CurrencySymbol  \
# 25833   My job status changed (promotion, new job, etc.)            USD
# 87353  Something else changed (education, award, medi...            USD
# 21895  Something else changed (education, award, medi...            USD
# 28080  I heard about a job opportunity (from a recrui...            USD
# 72274                   I was preparing for a job search            USD
# ...                                                  ...            ...
# 48179                   I was preparing for a job search            USD
# 57795                   I was preparing for a job search            USD
# 72568  I heard about a job opportunity (from a recrui...            USD
# 70575   My job status changed (promotion, new job, etc.)            USD
# 35725                   I was preparing for a job search            USD
#
#                CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 25833  United States dollar    65500.0   Weekly      2000000.0         45.0
# 87353  United States dollar    55000.0   Weekly      2000000.0         40.0
# 21895  United States dollar  1500000.0   Weekly      2000000.0         50.0
# 28080  United States dollar  2000000.0   Yearly      2000000.0         20.0
# 72274  United States dollar    80000.0   Weekly      2000000.0         40.0
# ...                     ...        ...      ...            ...          ...
# 48179  United States dollar   150000.0  Monthly      1800000.0         50.0
# 57795  United States dollar   150000.0  Monthly      1800000.0         50.0
# 72568  United States dollar   150000.0  Monthly      1800000.0         44.0
# 70575  United States dollar   150000.0  Monthly      1800000.0         50.0
# 35725  United States dollar   150000.0  Monthly      1800000.0         50.0
#
#                                                 WorkPlan  \
# 25833  There is a schedule and/or spec (made by me or...
# 87353  There is a schedule and/or spec (made by me or...
# 21895  There's no schedule or spec; I work on what se...
# 28080  There is a schedule and/or spec (made by me or...
# 72274  There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 48179  There's no schedule or spec; I work on what se...
# 57795  There is a schedule and/or spec (made by me or...
# 72568  There is a schedule and/or spec (made by me or...
# 70575  There's no schedule or spec; I work on what se...
# 35725  There is a schedule and/or spec (made by me or...
#
#                                            WorkChallenge  \
# 25833  Being tasked with non-development work;Meeting...
# 87353  Being tasked with non-development work;Meeting...
# 21895  Inadequate access to necessary tools;Meetings;...
# 28080  Being tasked with non-development work;Not eno...
# 72274  Lack of support from management;Meetings;Time ...
# ...                                                  ...
# 48179  Inadequate access to necessary tools;Non-work ...
# 57795  Lack of support from management;Not enough peo...
# 72568  Being tasked with non-development work;Meeting...
# 70575  Meetings;Non-work commitments (parenting, scho...
# 35725  Being tasked with non-development work;Distrac...
#
#                                               WorkRemote WorkLoc  \
# 25833                              A few days each month  Office
# 87353  All or almost all the time (I'm full-time remote)    Home
# 21895  All or almost all the time (I'm full-time remote)    Home
# 28080  All or almost all the time (I'm full-time remote)  Office
# 72274                   Less than once per month / Never  Office
# ...                                                  ...     ...
# 48179  All or almost all the time (I'm full-time remote)    Home
# 57795                              A few days each month  Office
# 72568                   Less than once per month / Never    Home
# 70575                              A few days each month  Office
# 35725                   Less than once per month / Never  Office
#
#                        ImpSyn                                  CodeRev  \
# 25833                 Average  Yes, because I see value in code review
# 87353  A little above average  Yes, because I see value in code review
# 21895  A little below average  Yes, because I see value in code review
# 28080       Far above average  Yes, because I see value in code review
# 72274  A little above average  Yes, because I see value in code review
# ...                       ...                                      ...
# 48179       Far above average  Yes, because I see value in code review
# 57795  A little above average  Yes, because I see value in code review
# 72568                 Average  Yes, because I see value in code review
# 70575  A little above average  Yes, because I see value in code review
# 35725  A little above average  Yes, because I see value in code review
#
#        CodeRevHrs                      UnitTests  \
# 25833         2.0  Yes, it's part of our process
# 87353         3.0      No, but I think we should
# 21895        10.0  Yes, it's part of our process
# 28080         NaN                            NaN
# 72274        10.0  Yes, it's part of our process
# ...           ...                            ...
# 48179         6.0  Yes, it's part of our process
# 57795         3.0  Yes, it's part of our process
# 72568        13.0      No, but I think we should
# 70575         2.0      No, but I think we should
# 35725         2.0  Yes, it's part of our process
#
#                                              PurchaseHow  \
# 25833  Developers and management have nearly equal in...
# 87353  Developers and management have nearly equal in...
# 21895  Developers typically have the most influence o...
# 28080                                                NaN
# 72274                                           Not sure
# ...                                                  ...
# 48179  Developers typically have the most influence o...
# 57795  Developers typically have the most influence o...
# 72568  Developers and management have nearly equal in...
# 70575  Developers typically have the most influence o...
# 35725                                                NaN
#
#                            PurchaseWhat  \
# 25833     I have little or no influence
# 87353  I have a great deal of influence
# 21895  I have a great deal of influence
# 28080                               NaN
# 72274     I have little or no influence
# ...                                 ...
# 48179             I have some influence
# 57795  I have a great deal of influence
# 72568     I have little or no influence
# 70575  I have a great deal of influence
# 35725     I have little or no influence
#
#                                       LanguageWorkedWith  \
# 25833  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 87353                        HTML/CSS;JavaScript;PHP;SQL
# 21895  Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 28080          C++;C#;Java;JavaScript;Objective-C;Python
# 72274                                    Java;Python;SQL
# ...                                                  ...
# 48179        Assembly;Bash/Shell/PowerShell;C;Python;SQL
# 57795  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 72568  C#;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;Ty...
# 70575          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 35725                                               Java
#
#                                   LanguageDesireNextYear  \
# 25833  Bash/Shell/PowerShell;C#;F#;Python;SQL;TypeScript
# 87353        HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 21895                                       Python;Swift
# 28080                                           C;C++;C#
# 72274                                                NaN
# ...                                                  ...
# 48179                                                NaN
# 57795  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 72568  C++;C#;HTML/CSS;Java;JavaScript;Objective-C;Sw...
# 70575     HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 35725                                        Java;Kotlin
#
#                                       DatabaseWorkedWith  \
# 25833                         Microsoft SQL Server;MySQL
# 87353                           MariaDB;MySQL;PostgreSQL
# 21895              Cassandra;Microsoft SQL Server;Oracle
# 28080                                  PostgreSQL;SQLite
# 72274  MongoDB;Microsoft SQL Server;MySQL;Oracle;Post...
# ...                                                  ...
# 48179                                  MariaDB;Other(s):
# 57795              Elasticsearch;PostgreSQL;Redis;SQLite
# 72568        Elasticsearch;MySQL;Oracle;PostgreSQL;Redis
# 70575                                         PostgreSQL
# 35725                                           DynamoDB
#
#                       DatabaseDesireNextYear  \
# 25833             Microsoft SQL Server;MySQL
# 87353               MariaDB;MySQL;PostgreSQL
# 21895                              Cassandra
# 28080                                 SQLite
# 72274                                  MySQL
# ...                                      ...
# 48179                              Other(s):
# 57795  Elasticsearch;PostgreSQL;Redis;SQLite
# 72568   Elasticsearch;MySQL;PostgreSQL;Redis
# 70575                             PostgreSQL
# 35725                               DynamoDB
#
#                                       PlatformWorkedWith  \
# 25833  AWS;Docker;Heroku;Linux;MacOS;Raspberry Pi;Win...
# 87353                                          WordPress
# 21895  Android;Arduino;Google Cloud Platform;IBM Clou...
# 28080                      Android;AWS;iOS;MacOS;Windows
# 72274                                    Android;Windows
# ...                                                  ...
# 48179                   IBM Cloud or Watson;Raspberry Pi
# 57795          AWS;Docker;Linux;MacOS;Raspberry Pi;Slack
# 72568                   AWS;Docker;Google Cloud Platform
# 70575                             AWS;Heroku;Linux;Slack
# 35725                                          AWS;Linux
#
#                                   PlatformDesireNextYear  \
# 25833                     AWS;Docker;Linux;MacOS;Windows
# 87353                                                NaN
# 21895                        IBM Cloud or Watson;Windows
# 28080                                      Android;Linux
# 72274                                         AWS;Docker
# ...                                                  ...
# 48179                                                NaN
# 57795  AWS;Docker;Google Cloud Platform;Linux;MacOS;R...
# 72568                   AWS;Docker;Google Cloud Platform
# 70575           Google Cloud Platform;Heroku;Linux;Slack
# 35725             AWS;Docker;Google Cloud Platform;Linux
#
#                                       WebFrameWorkedWith  \
# 25833                                 Angular/Angular.js
# 87353                              jQuery;Laravel;Vue.js
# 21895                                             jQuery
# 28080                                                NaN
# 72274                                                NaN
# ...                                                  ...
# 48179                                                NaN
# 57795  Angular/Angular.js;Django;Flask;jQuery;React.j...
# 72568        Flask;jQuery;Laravel;React.js;Spring;Vue.js
# 70575                                     Flask;React.js
# 35725                                             Spring
#
#                      WebFrameDesireNextYear  \
# 25833     Angular/Angular.js;Flask;React.js
# 87353  Express;Laravel;Ruby on Rails;Vue.js
# 21895                                   NaN
# 28080                                   NaN
# 72274           Angular/Angular.js;React.js
# ...                                     ...
# 48179                                   NaN
# 57795          Django;Flask;React.js;Vue.js
# 72568                React.js;Spring;Vue.js
# 70575                        Flask;React.js
# 35725                    Angular/Angular.js
#
#                              MiscTechWorkedWith  \
# 25833                    .NET;.NET Core;Node.js
# 87353                                       NaN
# 21895                                TensorFlow
# 28080                   Node.js;Pandas;Unity 3D
# 72274                                       NaN
# ...                                         ...
# 48179  Ansible;Apache Spark;Chef;Hadoop;Node.js
# 57795                           Ansible;Node.js
# 72568                       .NET;Node.js;Puppet
# 70575                                       NaN
# 35725                                       NaN
#
#                                   MiscTechDesireNextYear  \
# 25833                                  .NET Core;Node.js
# 87353                                            Node.js
# 21895                                         TensorFlow
# 28080                             Unity 3D;Unreal Engine
# 72274                                                NaN
# ...                                                  ...
# 48179                                                NaN
# 57795  Ansible;TensorFlow;Torch/PyTorch;Unity 3D;Othe...
# 72568  CryEngine;.NET;Node.js;Puppet;TensorFlow;Unity...
# 70575                                       React Native
# 35725                                                NaN
#
#                                               DevEnviron        OpSys  \
# 25833  Notepad++;Sublime Text;Vim;Visual Studio;Visua...      Windows
# 87353                Sublime Text;Vim;Visual Studio Code  Linux-based
# 21895                   Visual Studio;Visual Studio Code      Windows
# 28080  Android Studio;Coda;PyCharm;Visual Studio;Visu...        MacOS
# 72274                          Eclipse;Notepad++;PyCharm      Windows
# ...                                                  ...          ...
# 48179                                                Vim  Linux-based
# 57795  IPython / Jupyter;PyCharm;Sublime Text;Vim;Vis...  Linux-based
# 72568  Atom;Emacs;IntelliJ;Sublime Text;Vim;Visual St...      Windows
# 70575                                       Sublime Text        MacOS
# 35725                             IntelliJ;Notepad++;Vim  Linux-based
#
#                                               Containers  \
# 25833                             Development;Production
# 87353                            I do not use containers
# 21895                                        Development
# 28080                            I do not use containers
# 72274                                            Testing
# ...                                                  ...
# 48179                                         Production
# 57795                     Development;Testing;Production
# 72568  Testing;Production;Outside of work, for person...
# 70575                            I do not use containers
# 35725                     Development;Testing;Production
#
#                                  BlockchainOrg  \
# 25833                                      NaN
# 87353                               Not at all
# 21895      Implementing our own cryptocurrency
# 28080                                      NaN
# 72274                                      NaN
# ...                                        ...
# 48179  Non-currency applications of blockchain
# 57795                               Not at all
# 72568                               Not at all
# 70575                               Not at all
# 35725                               Not at all
#
#                                             BlockchainIs BetterLife ITperson  \
# 25833  Useful for decentralized currency (i.e., Bitcoin)         No      Yes
# 87353  Useful for immutable record keeping outside of...         No      Yes
# 21895  Useful across many domains and could change ma...        Yes      Yes
# 28080                  An irresponsible use of resources         No      Yes
# 72274                                                NaN        Yes      Yes
# ...                                                  ...        ...      ...
# 48179  Useful for immutable record keeping outside of...        Yes      Yes
# 57795  Useful for immutable record keeping outside of...        Yes      Yes
# 72568  Useful for immutable record keeping outside of...        Yes     SIGH
# 70575                  An irresponsible use of resources         No     SIGH
# 35725  Useful for decentralized currency (i.e., Bitcoin)        Yes     SIGH
#
#       OffOn               SocialMedia              Extraversion   ScreenName  \
# 25833   Yes                    Reddit  In real life (in person)     Username
# 87353   Yes                   Twitter                    Online       Handle
# 21895    No                   YouTube                    Online  Screen Name
# 28080    No  I don't use social media  In real life (in person)     Username
# 72274    No                  WhatsApp                   Neither          NaN
# ...     ...                       ...                       ...          ...
# 48179   Yes                  LinkedIn                    Online       UserID
# 57795   Yes                  Facebook  In real life (in person)     Username
# 72568    No                    Reddit                    Online     Username
# 70575   Yes                    Reddit  In real life (in person)     Username
# 35725   Yes                   Twitter  In real life (in person)     Username
#
#       SOVisit1st                      SOVisitFreq  \
# 25833       2013            Daily or almost daily
# 87353       2011            Daily or almost daily
# 21895        NaN             A few times per week
# 28080       2008            Daily or almost daily
# 72274       2017  A few times per month or weekly
# ...          ...                              ...
# 48179       2015             A few times per week
# 57795       2008             A few times per week
# 72568       2012           Multiple times per day
# 70575       2009             A few times per week
# 35725       2016  A few times per month or weekly
#
#                                                SOVisitTo  \
# 25833  Find answers to specific questions;Learn how t...
# 87353                 Find answers to specific questions
# 21895                 Find answers to specific questions
# 28080                 Find answers to specific questions
# 72274  Get a sense of belonging to the developer comm...
# ...                                                  ...
# 48179  Find answers to specific questions;Learn how t...
# 57795  Find answers to specific questions;Learn how t...
# 72568  Find answers to specific questions;Learn how t...
# 70575                 Find answers to specific questions
# 35725  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                         SOTimeSaved  \
# 25833           1-2 times per week      Stack Overflow was much faster
# 87353           3-5 times per week      Stack Overflow was much faster
# 21895           1-2 times per week      Stack Overflow was much faster
# 28080  More than 10 times per week      Stack Overflow was much faster
# 72274           1-2 times per week  Stack Overflow was slightly faster
# ...                            ...                                 ...
# 48179           3-5 times per week      Stack Overflow was much faster
# 57795           1-2 times per week  Stack Overflow was slightly faster
# 72568           3-5 times per week      Stack Overflow was much faster
# 70575           1-2 times per week  Stack Overflow was slightly faster
# 35725           3-5 times per week      Stack Overflow was much faster
#
#        SOHowMuchTime                  SOAccount  \
# 25833  11-30 minutes                        Yes
# 87353   0-10 minutes                        Yes
# 21895    60+ minutes                        Yes
# 28080    60+ minutes                        Yes
# 72274  11-30 minutes                        Yes
# ...              ...                        ...
# 48179  11-30 minutes  Not sure / can't remember
# 57795  31-60 minutes                        Yes
# 72568  11-30 minutes                        Yes
# 70575  31-60 minutes  Not sure / can't remember
# 35725  31-60 minutes                        Yes
#
#                                               SOPartFreq  \
# 25833                Less than once per month or monthly
# 87353                Less than once per month or monthly
# 21895  I have never participated in Q&A on Stack Over...
# 28080                             Multiple times per day
# 72274                    A few times per month or weekly
# ...                                                  ...
# 48179                                                NaN
# 57795  I have never participated in Q&A on Stack Over...
# 72568                Less than once per month or monthly
# 70575                                                NaN
# 35725                    A few times per month or weekly
#
#                                                   SOJobs  \
# 25833  No, I knew that Stack Overflow had a job board...
# 87353  No, I knew that Stack Overflow had a job board...
# 21895                                                Yes
# 28080                                                Yes
# 72274                                                Yes
# ...                                                  ...
# 48179  No, I didn't know that Stack Overflow had a jo...
# 57795                                                Yes
# 72568                                                Yes
# 70575  No, I didn't know that Stack Overflow had a jo...
# 35725  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams           SOComm  \
# 25833                No, and I don't know what those are   No, not really
# 87353  No, I've heard of them, but I am not part of a...   No, not really
# 21895                                                Yes  Yes, definitely
# 28080                No, and I don't know what those are  Yes, definitely
# 72274                No, and I don't know what those are         Not sure
# ...                                                  ...              ...
# 48179                No, and I don't know what those are          Neutral
# 57795  No, I've heard of them, but I am not part of a...   No, not really
# 72568                No, and I don't know what those are          Neutral
# 70575                No, and I don't know what those are   No, not at all
# 35725  No, I've heard of them, but I am not part of a...    Yes, somewhat
#
#                                   WelcomeChange  \
# 25833   Just as welcome now as I felt last year
# 87353   Just as welcome now as I felt last year
# 21895     A lot more welcome now than last year
# 28080     A lot less welcome now than last year
# 72274     A lot less welcome now than last year
# ...                                         ...
# 48179   Just as welcome now as I felt last year
# 57795   Just as welcome now as I felt last year
# 72568   Just as welcome now as I felt last year
# 70575   Just as welcome now as I felt last year
# 35725  Somewhat more welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 25833                                                NaN  24.0    Man    No
# 87353  Tech articles written by other developers;Tech...  32.0    Man    No
# 21895  Tech articles written by other developers;Indu...   NaN    Man    No
# 28080                Tech meetups or events in your area   NaN    NaN   NaN
# 72274  Tech articles written by other developers;Tech...   NaN    Man    No
# ...                                                  ...   ...    ...   ...
# 48179  Tech articles written by other developers;Tech...   NaN    Man    No
# 57795  Tech articles written by other developers;Indu...  38.0    Man    No
# 72568  Tech articles written by other developers;Indu...  26.0    Man    No
# 70575                                                NaN  26.0    Man    No
# 35725          Tech articles written by other developers  23.0    Man    No
#
#                      Sexuality  \
# 25833  Straight / Heterosexual
# 87353           Gay or Lesbian
# 21895  Straight / Heterosexual
# 28080  Straight / Heterosexual
# 72274                      NaN
# ...                        ...
# 48179  Straight / Heterosexual
# 57795  Straight / Heterosexual
# 72568  Straight / Heterosexual
# 70575  Straight / Heterosexual
# 35725           Gay or Lesbian
#
#                                               Ethnicity Dependents  \
# 25833                      White or of European descent         No
# 87353                      White or of European descent         No
# 21895                                               NaN        Yes
# 28080                                               NaN        Yes
# 72274                                               NaN        Yes
# ...                                                 ...        ...
# 48179                                       South Asian        Yes
# 57795                                        East Asian        Yes
# 72568                      White or of European descent        Yes
# 70575  East Asian;White or of European descent;Biracial         No
# 35725                      White or of European descent         No
#
#                 SurveyLength                  SurveyEase
# 25833  Appropriate in length                        Easy
# 87353  Appropriate in length  Neither easy nor difficult
# 21895               Too long                        Easy
# 28080              Too short                        Easy
# 72274               Too long                        Easy
# ...                      ...                         ...
# 48179               Too long                        Easy
# 57795  Appropriate in length                        Easy
# 72568               Too long                        Easy
# 70575  Appropriate in length                        Easy
# 35725  Appropriate in length                        Easy
#
# [750 rows x 85 columns]

# %% [markdown]
# ## Getting number of smalles values from dataframe
# For this purpose we use nsmallest() function

# %%
df.nsmallest(750, "ConvertedComp")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 28470       28638                     I am a developer by profession      Yes
# 719           722                     I am a developer by profession       No
# 13760       13825                     I am a developer by profession      Yes
# 40655       40913                     I am a developer by profession      Yes
# 30447       30630                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 65457       65874                     I am a developer by profession      Yes
# 72616       73075                     I am a developer by profession      Yes
# 36352       36578                     I am a developer by profession      Yes
# 53896       54236  I am not primarily a developer, but I write co...       No
# 53836       54176                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 28470  Less than once a month but more than once per ...
# 719    Less than once a month but more than once per ...
# 13760                                              Never
# 40655                            Less than once per year
# 30447  Less than once a month but more than once per ...
# ...                                                  ...
# 65457                         Once a month or more often
# 72616                            Less than once per year
# 36352                                              Never
# 53896                                              Never
# 53836                                              Never
#
#                                               OpenSource  \
# 28470  OSS is, on average, of HIGHER quality than pro...
# 719    The quality of OSS and closed source software ...
# 13760  The quality of OSS and closed source software ...
# 40655  The quality of OSS and closed source software ...
# 30447  The quality of OSS and closed source software ...
# ...                                                  ...
# 65457  OSS is, on average, of HIGHER quality than pro...
# 72616  OSS is, on average, of HIGHER quality than pro...
# 36352  OSS is, on average, of HIGHER quality than pro...
# 53896  The quality of OSS and closed source software ...
# 53836  The quality of OSS and closed source software ...
#
#                                               Employment         Country  \
# 28470  Independent contractor, freelancer, or self-em...     Afghanistan
# 719                                                  NaN     Afghanistan
# 13760                                                NaN         Algeria
# 40655                                 Employed full-time         Armenia
# 30447                                 Employed full-time       Australia
# ...                                                  ...             ...
# 65457                                 Employed part-time  Czech Republic
# 72616                                 Employed full-time           India
# 36352                                 Employed full-time     Philippines
# 53896                                 Employed part-time          Zambia
# 53836                                 Employed full-time            Iran
#
#       Student                                      EdLevel  \
# 28470     NaN    Other doctoral degree (Ph.D, Ed.D., etc.)
# 719       NaN                                          NaN
# 13760     NaN                                          NaN
# 40655      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 30447      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...       ...                                          ...
# 65457      No                    Primary/elementary school
# 72616      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 36352      No                             Associate degree
# 53896      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 53836      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  \
# 28470                           I never declared a major
# 719                                                  NaN
# 13760                                                NaN
# 40655  Computer science, computer engineering, or sof...
# 30447                                                NaN
# ...                                                  ...
# 65457                                                NaN
# 72616  Computer science, computer engineering, or sof...
# 36352  Information systems, information technology, o...
# 53896  Computer science, computer engineering, or sof...
# 53836  Information systems, information technology, o...
#
#                                                 EduOther  \
# 28470                                                NaN
# 719                                                  NaN
# 13760                                                NaN
# 40655  Taught yourself a new language, framework, or ...
# 30447  Taken an online course in programming or softw...
# ...                                                  ...
# 65457  Participated in a full-time developer training...
# 72616  Taught yourself a new language, framework, or ...
# 36352  Taught yourself a new language, framework, or ...
# 53896  Taken a part-time in-person course in programm...
# 53836  Taken an online course in programming or softw...
#
#                     OrgSize  \
# 28470                   NaN
# 719                     NaN
# 13760                   NaN
# 40655         2-9 employees
# 30447         2-9 employees
# ...                     ...
# 65457    20 to 99 employees
# 72616  100 to 499 employees
# 36352         2-9 employees
# 53896    20 to 99 employees
# 53836    10 to 19 employees
#
#                                                  DevType         YearsCode  \
# 28470                                                NaN                36
# 719                                                  NaN  Less than 1 year
# 13760                                                NaN                13
# 40655  Developer, desktop or enterprise applications;...                 7
# 30447  Database administrator;Developer, back-end;Dev...                35
# ...                                                  ...               ...
# 65457  Data scientist or machine learning specialist;...                 6
# 72616                              Developer, full-stack                 1
# 36352  Developer, back-end;Developer, front-end;Devel...                 5
# 53896                              Developer, QA or test                 5
# 53836  Data or business analyst;Data scientist or mac...                14
#
#                  Age1stCode      YearsCodePro  \
# 28470                    13                16
# 719    Younger than 5 years  Less than 1 year
# 13760                    83  Less than 1 year
# 40655                    15                 4
# 30447                     7                30
# ...                     ...               ...
# 65457                    12                 2
# 72616                     5                 1
# 36352                    15                 3
# 53896                    21                 1
# 53836                    20                14
#
#                                 CareerSat                              JobSat  \
# 28470                   Very dissatisfied                   Very dissatisfied
# 719                        Very satisfied                      Very satisfied
# 13760                   Very dissatisfied                      Very satisfied
# 40655                  Slightly satisfied                  Slightly satisfied
# 30447  Neither satisfied nor dissatisfied                      Very satisfied
# ...                                   ...                                 ...
# 65457                  Slightly satisfied                  Slightly satisfied
# 72616  Neither satisfied nor dissatisfied               Slightly dissatisfied
# 36352                      Very satisfied                      Very satisfied
# 53896  Neither satisfied nor dissatisfied  Neither satisfied nor dissatisfied
# 53836                      Very satisfied                      Very satisfied
#
#                      MgrIdiot  MgrMoney                 MgrWant  \
# 28470                     NaN       NaN                     NaN
# 719                       NaN       NaN                     NaN
# 13760                     NaN       NaN                     NaN
# 40655          Very confident  Not sure                Not sure
# 30447                     NaN       NaN                     NaN
# ...                       ...       ...                     ...
# 65457  I don't have a manager        No                      No
# 72616    Not at all confident        No                     Yes
# 36352          Very confident        No                Not sure
# 53896          Very confident       Yes                     Yes
# 53836  I don't have a manager        No  I am already a manager
#
#                                                  JobSeek  \
# 28470       I am not interested in new job opportunities
# 719         I am not interested in new job opportunities
# 13760                    I am actively looking for a job
# 40655       I am not interested in new job opportunities
# 30447       I am not interested in new job opportunities
# ...                                                  ...
# 65457  I’m not actively looking, but I am open to new...
# 72616  I’m not actively looking, but I am open to new...
# 36352  I’m not actively looking, but I am open to new...
# 53896  I’m not actively looking, but I am open to new...
# 53836       I am not interested in new job opportunities
#
#                                             LastHireDate  \
# 28470                                                NaN
# 719    NA - I am an independent contractor or self em...
# 13760  NA - I am an independent contractor or self em...
# 40655                               Less than a year ago
# 30447  NA - I am an independent contractor or self em...
# ...                                                  ...
# 65457                                      1-2 years ago
# 72616                                      1-2 years ago
# 36352                                      3-4 years ago
# 53896                               Less than a year ago
# 53836                                      3-4 years ago
#
#                                                  LastInt FizzBuzz  \
# 28470                                                NaN      NaN
# 719                                                  NaN       No
# 13760  Complete a take-home project;Solve a brain-tea...      Yes
# 40655  Write any code;Write code by hand (e.g., on a ...       No
# 30447  Interview with people in peer roles;Interview ...       No
# ...                                                  ...      ...
# 65457  Write any code;Write code by hand (e.g., on a ...       No
# 72616  Write any code;Write code by hand (e.g., on a ...      NaN
# 36352  Interview with people in senior / management r...       No
# 53896        Write any code;Complete a take-home project       No
# 53836  Interview with people in senior / management r...       No
#
#                                               JobFactors  \
# 28470                                                NaN
# 719                                                  NaN
# 13760  Financial performance or funding status of the...
# 40655  Industry that I'd be working in;Languages, fra...
# 30447  Industry that I'd be working in;Office environ...
# ...                                                  ...
# 65457  Languages, frameworks, and other technologies ...
# 72616  Languages, frameworks, and other technologies ...
# 36352  Languages, frameworks, and other technologies ...
# 53896  Industry that I'd be working in;Office environ...
# 53836  Office environment or company culture;How wide...
#
#                                             ResumeUpdate CurrencySymbol  \
# 28470                                                NaN            AFN
# 719    I heard about a job opportunity (from a recrui...            AFN
# 13760  Something else changed (education, award, medi...            AFN
# 40655  Something else changed (education, award, medi...            AMD
# 30447  I heard about a job opportunity (from a recrui...            AUD
# ...                                                  ...            ...
# 65457  Something else changed (education, award, medi...            CZK
# 72616                   I was preparing for a job search            INR
# 36352  I heard about a job opportunity (from a recrui...            PHP
# 53896                   I was preparing for a job search            ZMW
# 53836                   I was preparing for a job search            IRR
#
#             CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 28470     Afghan afghani        3.0  Monthly            0.0          2.0
# 719       Afghan afghani        1.0   Yearly            0.0          1.0
# 13760     Afghan afghani        1.0   Yearly            0.0        168.0
# 40655      Armenian dram        0.0  Monthly            0.0         40.0
# 30447  Australian dollar        0.0   Yearly            0.0         80.0
# ...                  ...        ...      ...            ...          ...
# 65457       Czech koruna     3000.0  Monthly         1608.0          7.0
# 72616       Indian rupee     9580.0  Monthly         1608.0          9.0
# 36352    Philippine peso     7000.0  Monthly         1608.0          8.0
# 53896     Zambian kwacha     1600.0  Monthly         1608.0         40.0
# 53836       Iranian rial  5700000.0  Monthly         1620.0         60.0
#
#                                                 WorkPlan  \
# 28470                                                NaN
# 719                                                  NaN
# 13760                                                NaN
# 40655  There's no schedule or spec; I work on what se...
# 30447  There's no schedule or spec; I work on what se...
# ...                                                  ...
# 65457  There's no schedule or spec; I work on what se...
# 72616  There is a schedule and/or spec (made by me or...
# 36352  There's no schedule or spec; I work on what se...
# 53896  There is a schedule and/or spec (made by me or...
# 53836  There is a schedule and/or spec (made by me or...
#
#                                            WorkChallenge  \
# 28470                                                NaN
# 719                                                  NaN
# 13760  Being tasked with non-development work;Non-wor...
# 40655  Meetings;Non-work commitments (parenting, scho...
# 30447  Distracting work environment;Non-work commitme...
# ...                                                  ...
# 65457  Being tasked with non-development work;Distrac...
# 72616  Lack of support from management;Not enough peo...
# 36352  Being tasked with non-development work;Inadequ...
# 53896  Distracting work environment;Lack of support f...
# 53836  Being tasked with non-development work;Distrac...
#
#                                               WorkRemote  \
# 28470                                                NaN
# 719                     Less than once per month / Never
# 13760                                About half the time
# 40655  Less than half the time, but at least one day ...
# 30447                                   It's complicated
# ...                                                  ...
# 65457                   Less than once per month / Never
# 72616                                                NaN
# 36352                   Less than once per month / Never
# 53896                   Less than once per month / Never
# 53836                   Less than once per month / Never
#
#                                               WorkLoc                  ImpSyn  \
# 28470                                             NaN                     NaN
# 719    Other place, such as a coworking space or cafe       Far above average
# 13760                                            Home       Far above average
# 40655                                          Office  A little above average
# 30447  Other place, such as a coworking space or cafe  A little above average
# ...                                               ...                     ...
# 65457                                            Home  A little above average
# 72616                                          Office       Far above average
# 36352                                          Office  A little above average
# 53896                                          Office  A little above average
# 53836                                          Office       Far above average
#
#                                        CodeRev  CodeRevHrs  \
# 28470                                      NaN         NaN
# 719    Yes, because I see value in code review         1.0
# 13760                                       No         NaN
# 40655  Yes, because I see value in code review         3.0
# 30447  Yes, because I see value in code review        10.0
# ...                                        ...         ...
# 65457                                       No         NaN
# 72616  Yes, because I see value in code review         1.0
# 36352  Yes, because I see value in code review        15.0
# 53896                                       No         NaN
# 53836  Yes, because I see value in code review         3.0
#
#                                                UnitTests  \
# 28470                                                NaN
# 719                            No, and I'm glad we don't
# 13760                      Yes, it's part of our process
# 40655                          No, and I'm glad we don't
# 30447                          No, but I think we should
# ...                                                  ...
# 65457                          No, but I think we should
# 72616                          No, but I think we should
# 36352                          No, and I'm glad we don't
# 53896  Yes, it's not part of our process but the deve...
# 53836                          No, but I think we should
#
#                                              PurchaseHow  \
# 28470                                                NaN
# 719                                                  NaN
# 13760                                                NaN
# 40655  Developers and management have nearly equal in...
# 30447                                                NaN
# ...                                                  ...
# 65457  Developers typically have the most influence o...
# 72616                                           Not sure
# 36352  Developers typically have the most influence o...
# 53896  Developers and management have nearly equal in...
# 53836  The CTO, CIO, or other management purchase new...
#
#                            PurchaseWhat  \
# 28470                               NaN
# 719       I have little or no influence
# 13760  I have a great deal of influence
# 40655  I have a great deal of influence
# 30447  I have a great deal of influence
# ...                                 ...
# 65457             I have some influence
# 72616     I have little or no influence
# 36352  I have a great deal of influence
# 53896     I have little or no influence
# 53836  I have a great deal of influence
#
#                                       LanguageWorkedWith  \
# 28470  Bash/Shell/PowerShell;C;C++;Java;Objective-C;O...
# 719                                                  NaN
# 13760                                          Other(s):
# 40655  Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...
# 30447     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Ruby
# ...                                                  ...
# 65457  Bash/Shell/PowerShell;C;C++;C#;HTML/CSS;Java;J...
# 72616                                     JavaScript;PHP
# 36352                     C#;HTML/CSS;JavaScript;PHP;SQL
# 53896                C#;HTML/CSS;Java;JavaScript;PHP;SQL
# 53836                       C#;HTML/CSS;JavaScript;R;SQL
#
#                                   LanguageDesireNextYear  \
# 28470  Bash/Shell/PowerShell;C;C++;Java;Objective-C;O...
# 719                                                  NaN
# 13760                                          Other(s):
# 40655                   C;C++;Java;Python;SQL;TypeScript
# 30447                             Elixir;Ruby;TypeScript
# ...                                                  ...
# 65457  Assembly;Bash/Shell/PowerShell;C++;C#;Python;Ruby
# 72616                              JavaScript;PHP;Python
# 36352         C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 53896                                      Elixir;Kotlin
# 53836                  C#;HTML/CSS;JavaScript;Python;SQL
#
#                                       DatabaseWorkedWith  \
# 28470                                       MySQL;SQLite
# 719                                                  NaN
# 13760                                          Other(s):
# 40655          Elasticsearch;MariaDB;MongoDB;MySQL;Redis
# 30447                                         PostgreSQL
# ...                                                  ...
# 65457          MariaDB;Microsoft SQL Server;MySQL;SQLite
# 72616                                              MySQL
# 36352                  Microsoft SQL Server;MySQL;SQLite
# 53896  MariaDB;Microsoft SQL Server;MySQL;Oracle;Post...
# 53836                               Microsoft SQL Server
#
#                                 DatabaseDesireNextYear  \
# 28470                                     MySQL;SQLite
# 719                                                NaN
# 13760                                        Other(s):
# 40655                            MariaDB;MongoDB;MySQL
# 30447                                       PostgreSQL
# ...                                                ...
# 65457  MariaDB;Microsoft SQL Server;MySQL;Redis;SQLite
# 72616                                    MongoDB;MySQL
# 36352                Microsoft SQL Server;MySQL;SQLite
# 53896                           Firebase;MongoDB;Redis
# 53836                             Microsoft SQL Server
#
#                                       PlatformWorkedWith  \
# 28470                            Android;iOS;Linux;MacOS
# 719                                                  NaN
# 13760                                          Other(s):
# 40655  Arduino;AWS;Docker;Linux;MacOS;Raspberry Pi;Sl...
# 30447                                            AWS;iOS
# ...                                                  ...
# 65457  Android;Arduino;AWS;Docker;Linux;Raspberry Pi;...
# 72616                                              Linux
# 36352                                            Android
# 53896              Android;Linux;Slack;Windows;WordPress
# 53836                                            Windows
#
#                                   PlatformDesireNextYear  \
# 28470                                  Android;iOS;Linux
# 719                                                  NaN
# 13760                                          Other(s):
# 40655                   Arduino;Linux;MacOS;Raspberry Pi
# 30447                                    Android;AWS;iOS
# ...                                                  ...
# 65457  Arduino;Docker;Kubernetes;Linux;Raspberry Pi;W...
# 72616                                              Linux
# 36352                                Android;Arduino;iOS
# 53896           Android;AWS;Docker;Google Cloud Platform
# 53836                                            Windows
#
#                    WebFrameWorkedWith  \
# 28470                          jQuery
# 719                               NaN
# 13760                       Other(s):
# 40655            ASP.NET;Django;Flask
# 30447            Ruby on Rails;Vue.js
# ...                               ...
# 65457                          jQuery
# 72616              Angular/Angular.js
# 36352                          jQuery
# 53896  ASP.NET;Drupal;jQuery;React.js
# 53836                         ASP.NET
#
#                                   WebFrameDesireNextYear  \
# 28470                                                NaN
# 719                                                  NaN
# 13760                                          Other(s):
# 40655                                       Django;Flask
# 30447                               Ruby on Rails;Vue.js
# ...                                                  ...
# 65457                                                NaN
# 72616  Angular/Angular.js;Django;Express;React.js;Vue.js
# 36352              jQuery;Laravel;React.js;Ruby on Rails
# 53896  Angular/Angular.js;Express;Laravel;Ruby on Rai...
# 53836                            ASP.NET;Django;React.js
#
#                                       MiscTechWorkedWith  \
# 28470                                TensorFlow;Unity 3D
# 719                                                  NaN
# 13760                                          Other(s):
# 40655              .NET;Node.js;TensorFlow;Torch/PyTorch
# 30447                                  Chef;React Native
# ...                                                  ...
# 65457  Ansible;.NET;.NET Core;Pandas;TensorFlow;Torch...
# 72616                                                NaN
# 36352                                   Unity 3D;Xamarin
# 53896                     Cordova;.NET;.NET Core;Node.js
# 53836                                               .NET
#
#                                   MiscTechDesireNextYear  \
# 28470                         Hadoop;TensorFlow;Unity 3D
# 719                                                  NaN
# 13760                                          Other(s):
# 40655                                            Node.js
# 30447                                       React Native
# ...                                                  ...
# 65457                 .NET Core;TensorFlow;Torch/PyTorch
# 72616                                            Node.js
# 36352  .NET Core;React Native;Unity 3D;Unreal Engine;...
# 53896           CryEngine;Unity 3D;Unreal Engine;Xamarin
# 53836  .NET Core;Pandas;React Native;TensorFlow;Torch...
#
#                                               DevEnviron        OpSys  \
# 28470                                              Emacs  Linux-based
# 719                                                  NaN          NaN
# 13760                                                NaN          NaN
# 40655        IntelliJ;IPython / Jupyter;Sublime Text;Vim  Linux-based
# 30447                    Sublime Text;TextMate;Vim;Xcode        MacOS
# ...                                                  ...          ...
# 65457               Vim;Visual Studio;Visual Studio Code  Linux-based
# 72616                        NetBeans;Visual Studio Code  Linux-based
# 36352      Sublime Text;Visual Studio;Visual Studio Code      Windows
# 53896  Android Studio;IntelliJ;NetBeans;Notepad++;Vis...      Windows
# 53836  IPython / Jupyter;Visual Studio;Visual Studio ...      Windows
#
#                                               Containers  \
# 28470                            I do not use containers
# 719                                                  NaN
# 13760                            I do not use containers
# 40655                                         Production
# 30447                            I do not use containers
# ...                                                  ...
# 65457  Development;Testing;Production;Outside of work...
# 72616                            I do not use containers
# 36352                            I do not use containers
# 53896                            I do not use containers
# 53836                            I do not use containers
#
#                                            BlockchainOrg  \
# 28470                                                NaN
# 719                                                  NaN
# 13760                                                NaN
# 40655                                         Not at all
# 30447                                         Not at all
# ...                                                  ...
# 65457                                         Not at all
# 72616  Accepting Bitcoin or other coins and tokens as...
# 36352                                                NaN
# 53896                                                NaN
# 53836                                         Not at all
#
#                                             BlockchainIs BetterLife  \
# 28470  Useful for immutable record keeping outside of...         No
# 719                                                  NaN         No
# 13760                  An irresponsible use of resources         No
# 40655                                      A passing fad         No
# 30447                  An irresponsible use of resources        Yes
# ...                                                  ...        ...
# 65457  Useful for immutable record keeping outside of...        Yes
# 72616  Useful across many domains and could change ma...        Yes
# 36352                                                NaN        Yes
# 53896                                                NaN         No
# 53836                                      A passing fad        Yes
#
#                                        ITperson  OffOn SocialMedia  \
# 28470                                       Yes     No         NaN
# 719                                        SIGH  What?         NaN
# 13760                                       Yes    Yes         NaN
# 40655                                      SIGH    Yes    Facebook
# 30447  Fortunately, someone else has that title     No      Reddit
# ...                                         ...    ...         ...
# 65457                                      SIGH    Yes     Twitter
# 72616                                       Yes     No     YouTube
# 36352                                       Yes    Yes    Facebook
# 53896                                       Yes    Yes    Facebook
# 53836                                       Yes     No         NaN
#
#                    Extraversion   ScreenName        SOVisit1st  \
# 28470  In real life (in person)     Username              2008
# 719                     Neither          NaN              2008
# 13760                   Neither          NaN              2015
# 40655  In real life (in person)     Username              2013
# 30447                    Online     Username  I don't remember
# ...                         ...          ...               ...
# 65457                    Online       Handle              2012
# 72616  In real life (in person)  Screen Name              2018
# 36352  In real life (in person)     Username              2015
# 53896  In real life (in person)     Username              2013
# 53836  In real life (in person)     Username              2013
#
#                            SOVisitFreq  \
# 28470            Daily or almost daily
# 719             Multiple times per day
# 13760  A few times per month or weekly
# 40655           Multiple times per day
# 30447  A few times per month or weekly
# ...                                ...
# 65457           Multiple times per day
# 72616           Multiple times per day
# 36352           Multiple times per day
# 53896            Daily or almost daily
# 53836             A few times per week
#
#                                                SOVisitTo  \
# 28470                 Find answers to specific questions
# 719                                                  NaN
# 13760                 Find answers to specific questions
# 40655  Find answers to specific questions;Learn how t...
# 30447                 Find answers to specific questions
# ...                                                  ...
# 65457                 Find answers to specific questions
# 72616                 Find answers to specific questions
# 36352  Learn how to do things I didn’t necessarily lo...
# 53896                 Find answers to specific questions
# 53836                 Find answers to specific questions
#
#                       SOFindAnswer                         SOTimeSaved  \
# 28470          6-10 times per week  The other resource was much faster
# 719    More than 10 times per week  The other resource was much faster
# 13760           1-2 times per week            They were about the same
# 40655           3-5 times per week      Stack Overflow was much faster
# 30447           1-2 times per week            They were about the same
# ...                            ...                                 ...
# 65457           3-5 times per week      Stack Overflow was much faster
# 72616  More than 10 times per week      Stack Overflow was much faster
# 36352           3-5 times per week      Stack Overflow was much faster
# 53896  More than 10 times per week      Stack Overflow was much faster
# 53836           1-2 times per week      Stack Overflow was much faster
#
#        SOHowMuchTime                  SOAccount  \
# 28470  11-30 minutes                        Yes
# 719      60+ minutes  Not sure / can't remember
# 13760            NaN                        Yes
# 40655   0-10 minutes                        Yes
# 30447            NaN                        Yes
# ...              ...                        ...
# 65457  31-60 minutes                        Yes
# 72616    60+ minutes                        Yes
# 36352  31-60 minutes                        Yes
# 53896  31-60 minutes                        Yes
# 53836    60+ minutes                        Yes
#
#                                               SOPartFreq  \
# 28470                Less than once per month or monthly
# 719                                                  NaN
# 13760  I have never participated in Q&A on Stack Over...
# 40655                Less than once per month or monthly
# 30447                Less than once per month or monthly
# ...                                                  ...
# 65457  I have never participated in Q&A on Stack Over...
# 72616                Less than once per month or monthly
# 36352                             Multiple times per day
# 53896                Less than once per month or monthly
# 53836  I have never participated in Q&A on Stack Over...
#
#                                                   SOJobs  \
# 28470                                                Yes
# 719                                                  Yes
# 13760  No, I knew that Stack Overflow had a job board...
# 40655  No, I knew that Stack Overflow had a job board...
# 30447  No, I knew that Stack Overflow had a job board...
# ...                                                  ...
# 65457  No, I knew that Stack Overflow had a job board...
# 72616  No, I knew that Stack Overflow had a job board...
# 36352  No, I knew that Stack Overflow had a job board...
# 53896                                                Yes
# 53836  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams           SOComm  \
# 28470  No, I've heard of them, but I am not part of a...   No, not at all
# 719                                                  Yes         Not sure
# 13760                No, and I don't know what those are   No, not at all
# 40655  No, I've heard of them, but I am not part of a...   No, not really
# 30447                No, and I don't know what those are   No, not really
# ...                                                  ...              ...
# 65457                No, and I don't know what those are   No, not really
# 72616                No, and I don't know what those are    Yes, somewhat
# 36352  No, I've heard of them, but I am not part of a...  Yes, definitely
# 53896                No, and I don't know what those are          Neutral
# 53836                No, and I don't know what those are          Neutral
#
#                                            WelcomeChange  \
# 28470              A lot less welcome now than last year
# 719    Not applicable - I did not use Stack Overflow ...
# 13760              A lot less welcome now than last year
# 40655            Just as welcome now as I felt last year
# 30447              A lot less welcome now than last year
# ...                                                  ...
# 65457            Just as welcome now as I felt last year
# 72616              A lot more welcome now than last year
# 36352              A lot more welcome now than last year
# 53896            Just as welcome now as I felt last year
# 53836            Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 28470                                                NaN   NaN    NaN   NaN
# 719                                                  NaN   1.0    NaN   NaN
# 13760                                                NaN  56.0    NaN   NaN
# 40655          Tech articles written by other developers  22.0    Man    No
# 30447                                                NaN  43.0    NaN    No
# ...                                                  ...   ...    ...   ...
# 65457                                                NaN  18.0    Man    No
# 72616  Tech articles written by other developers;Indu...  25.0    Man    No
# 36352  Tech articles written by other developers;Indu...  23.0    Man    No
# 53896  Tech articles written by other developers;Tech...  26.0    Man    No
# 53836  Tech articles written by other developers;Indu...  33.0    Man    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 28470                      NaN                           NaN        NaN
# 719                        NaN                           NaN        NaN
# 13760                      NaN                           NaN        Yes
# 40655  Straight / Heterosexual                           NaN         No
# 30447                      NaN                           NaN         No
# ...                        ...                           ...        ...
# 65457           Gay or Lesbian  White or of European descent         No
# 72616  Straight / Heterosexual                   South Asian         No
# 36352  Straight / Heterosexual                   South Asian         No
# 53896  Straight / Heterosexual   Black or of African descent         No
# 53836                      NaN                Middle Eastern         No
#
#                 SurveyLength                  SurveyEase
# 28470               Too long                         NaN
# 719                 Too long                   Difficult
# 13760              Too short                        Easy
# 40655  Appropriate in length                        Easy
# 30447  Appropriate in length                        Easy
# ...                      ...                         ...
# 65457  Appropriate in length                        Easy
# 72616  Appropriate in length  Neither easy nor difficult
# 36352  Appropriate in length  Neither easy nor difficult
# 53896  Appropriate in length  Neither easy nor difficult
# 53836  Appropriate in length                        Easy
#
# [750 rows x 85 columns]
